# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Parks & Trails Data

# %% [markdown]
# ### Parks Data

# %%
# Load the parks data from the parks.csv

parks_data_to_load = "./Resources/parks.csv"
parks_df = pd.read_csv(parks_data_to_load, encoding="utf-8")
parks_df.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
#Standardize the column names to lowercase & underscores:

renamed_parks_df = parks_df.rename(columns={"Park Code": "park_code",
                                        "Park Name": "park_name",
                                        "State": "state",
                                        "Acres": "acres",
                                        "Latitude": "latitude",
                                        "Longitude": "longitude",
                                                                    })
renamed_parks_df
# Out:
#    park_code                                       park_name       state  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# 12      CRLA                       Crater Lake National Park          OR
# 13      CUVA                   Cuyahoga Valley National Park          OH
# 14      DENA               Denali National Park and Preserve          AK
# 15      DEVA                      Death Valley National Park      CA, NV
# 16      DRTO                      Dry Tortugas National Park          FL
# 17      EVER                        Everglades National Park          FL
# 18      GAAR  Gates Of The Arctic National Park and Preserve          AK
# 19      GLAC                           Glacier National Park          MT
# 20      GLBA          Glacier Bay National Park and Preserve          AK
# 21      GRBA                       Great Basin National Park          NV
# 22      GRCA                      Grand Canyon National Park          AZ
# 23      GRSA     Great Sand Dunes National Park and Preserve          CO
# 24      GRSM             Great Smoky Mountains National Park      TN, NC
# 25      GRTE                       Grand Teton National Park          WY
# 26      GUMO               Guadalupe Mountains National Park          TX
# 27      HALE                         Haleakala National Park          HI
# 28      HAVO                  Hawaii Volcanoes National Park          HI
# 29      HOSP                       Hot Springs National Park          AR
# 30      ISRO                       Isle Royale National Park          MI
# 31      JOTR                       Joshua Tree National Park          CA
# 32      KATM               Katmai National Park and Preserve          AK
# 33      KEFJ                      Kenai Fjords National Park          AK
# 34      KOVA                      Kobuk Valley National Park          AK
# 35      LACL           Lake Clark National Park and Preserve          AK
# 36      LAVO                   Lassen Volcanic National Park          CA
# 37      MACA                      Mammoth Cave National Park          KY
# 38      MEVE                        Mesa Verde National Park          CO
# 39      MORA                     Mount Rainier National Park          WA
# 40      NOCA                    North Cascades National Park          WA
# 41      OLYM                           Olympic National Park          WA
# 42      PEFO                  Petrified Forest National Park          AZ
# 43      PINN                         Pinnacles National Park          CA
# 44      REDW                           Redwood National Park          CA
# 45      ROMO                    Rocky Mountain National Park          CO
# 46      SAGU                           Saguaro National Park          AZ
# 47      SEKI         Sequoia and Kings Canyon National Parks          CA
# 48      SHEN                        Shenandoah National Park          VA
# 49      THRO                Theodore Roosevelt National Park          ND
# 50      VOYA                         Voyageurs National Park          MN
# 51      WICA                         Wind Cave National Park          SD
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
# 54      YOSE                          Yosemite National Park          CA
# 55      ZION                              Zion National Park          UT
#
#       acres  latitude  longitude
# 0     47390     44.35     -68.21
# 1     76519     38.68    -109.57
# 2    242756     43.75    -102.50
# 3    801163     29.25    -103.25
# 4    172924     25.65     -80.08
# 5     32950     38.57    -107.72
# 6     35835     37.57    -112.18
# 7    337598     38.20    -109.93
# 8    241904     38.20    -111.17
# 9     46766     32.17    -104.44
# 10   249561     34.01    -119.42
# 11    26546     33.78     -80.78
# 12   183224     42.94    -122.10
# 13    32950     41.24     -81.55
# 14  3372402     63.33    -150.50
# 15  4740912     36.24    -116.82
# 16    64701     24.63     -82.87
# 17  1508538     25.32     -80.93
# 18  7523898     67.78    -153.30
# 19  1013572     48.80    -114.00
# 20  3224840     58.50    -137.00
# 21    77180     38.98    -114.30
# 22  1217403     36.06    -112.14
# 23    42984     37.73    -105.51
# 24   521490     35.68     -83.53
# 25   309995     43.73    -110.80
# 26    86416     31.92    -104.87
# 27    29094     20.72    -156.17
# 28   323431     19.38    -155.20
# 29     5550     34.51     -93.05
# 30   571790     48.10     -88.55
# 31   789745     33.79    -115.90
# 32  3674530     58.50    -155.00
# 33   669983     59.92    -149.65
# 34  1750717     67.55    -159.28
# 35  2619733     60.97    -153.42
# 36   106372     40.49    -121.51
# 37    52830     37.18     -86.10
# 38    52122     37.18    -108.49
# 39   235625     46.85    -121.75
# 40   504781     48.70    -121.20
# 41   922651     47.97    -123.50
# 42    93533     35.07    -109.78
# 43    26606     36.48    -121.16
# 44   112512     41.30    -124.00
# 45   265828     40.40    -105.58
# 46    91440     32.25    -110.50
# 47   865952     36.43    -118.68
# 48   199045     38.53     -78.35
# 49    70447     46.97    -103.45
# 50   218200     48.50     -92.88
# 51    28295     43.57    -103.48
# 52  8323148     61.00    -142.00
# 53  2219791     44.60    -110.50
# 54   761266     37.83    -119.50
# 55   146598     37.30    -113.05

# %%
# Remove any words after the work "Park" in park_names:

p = '(.*Park)'
park_name_parks = renamed_parks_df["park_name"].str.extract(p)
park_name_parks.value_counts()
# Out:
# Acadia National Park                          1
# Arches National Park                          1
# Isle Royale National Park                     1
# Joshua Tree National Park                     1
# Katmai National Park                          1
# Kenai Fjords National Park                    1
# Kobuk Valley National Park                    1
# Lake Clark National Park                      1
# Lassen Volcanic National Park                 1
# Mammoth Cave National Park                    1
# Mesa Verde National Park                      1
# Mount Rainier National Park                   1
# North Cascades National Park                  1
# Olympic National Park                         1
# Petrified Forest National Park                1
# Pinnacles National Park                       1
# Redwood National Park                         1
# Rocky Mountain National Park                  1
# Saguaro National Park                         1
# Sequoia and Kings Canyon National Park        1
# Shenandoah National Park                      1
# Theodore Roosevelt National Park              1
# Voyageurs National Park                       1
# Wind Cave National Park                       1
# Wrangell - St Elias National Park             1
# Yellowstone National Park                     1
# Yosemite National Park                        1
# Hot Springs National Park                     1
# Hawaii Volcanoes National Park                1
# Haleakala National Park                       1
# Cuyahoga Valley National Park                 1
# Badlands National Park                        1
# Big Bend National Park                        1
# Biscayne National Park                        1
# Black Canyon of the Gunnison National Park    1
# Bryce Canyon National Park                    1
# Canyonlands National Park                     1
# Capitol Reef National Park                    1
# Carlsbad Caverns National Park                1
# Channel Islands National Park                 1
# Congaree National Park                        1
# Crater Lake National Park                     1
# Death Valley National Park                    1
# Guadalupe Mountains National Park             1
# Denali National Park                          1
# Dry Tortugas National Park                    1
# Everglades National Park                      1
# Gates Of The Arctic National Park             1
# Glacier Bay National Park                     1
# Glacier National Park                         1
# Grand Canyon National Park                    1
# Grand Teton National Park                     1
# Great Basin National Park                     1
# Great Sand Dunes National Park                1
# Great Smoky Mountains National Park           1
# Zion National Park                            1
# dtype: int64

# %%
# Final clean of parks_df - columns standardized, and anything after "parks" is removed:
# Edited Park Names are replace original Park Names
renamed_parks_df["park_name"] = park_name_parks.values
parks_final_df = renamed_parks_df

#Check the final df and make sure its all there!
parks_final_df
# Out:
#    park_code                                   park_name       state    acres  \
# 0       ACAD                        Acadia National Park          ME    47390
# 1       ARCH                        Arches National Park          UT    76519
# 2       BADL                      Badlands National Park          SD   242756
# 3       BIBE                      Big Bend National Park          TX   801163
# 4       BISC                      Biscayne National Park          FL   172924
# 5       BLCA  Black Canyon of the Gunnison National Park          CO    32950
# 6       BRCA                  Bryce Canyon National Park          UT    35835
# 7       CANY                   Canyonlands National Park          UT   337598
# 8       CARE                  Capitol Reef National Park          UT   241904
# 9       CAVE              Carlsbad Caverns National Park          NM    46766
# 10      CHIS               Channel Islands National Park          CA   249561
# 11      CONG                      Congaree National Park          SC    26546
# 12      CRLA                   Crater Lake National Park          OR   183224
# 13      CUVA               Cuyahoga Valley National Park          OH    32950
# 14      DENA                        Denali National Park          AK  3372402
# 15      DEVA                  Death Valley National Park      CA, NV  4740912
# 16      DRTO                  Dry Tortugas National Park          FL    64701
# 17      EVER                    Everglades National Park          FL  1508538
# 18      GAAR           Gates Of The Arctic National Park          AK  7523898
# 19      GLAC                       Glacier National Park          MT  1013572
# 20      GLBA                   Glacier Bay National Park          AK  3224840
# 21      GRBA                   Great Basin National Park          NV    77180
# 22      GRCA                  Grand Canyon National Park          AZ  1217403
# 23      GRSA              Great Sand Dunes National Park          CO    42984
# 24      GRSM         Great Smoky Mountains National Park      TN, NC   521490
# 25      GRTE                   Grand Teton National Park          WY   309995
# 26      GUMO           Guadalupe Mountains National Park          TX    86416
# 27      HALE                     Haleakala National Park          HI    29094
# 28      HAVO              Hawaii Volcanoes National Park          HI   323431
# 29      HOSP                   Hot Springs National Park          AR     5550
# 30      ISRO                   Isle Royale National Park          MI   571790
# 31      JOTR                   Joshua Tree National Park          CA   789745
# 32      KATM                        Katmai National Park          AK  3674530
# 33      KEFJ                  Kenai Fjords National Park          AK   669983
# 34      KOVA                  Kobuk Valley National Park          AK  1750717
# 35      LACL                    Lake Clark National Park          AK  2619733
# 36      LAVO               Lassen Volcanic National Park          CA   106372
# 37      MACA                  Mammoth Cave National Park          KY    52830
# 38      MEVE                    Mesa Verde National Park          CO    52122
# 39      MORA                 Mount Rainier National Park          WA   235625
# 40      NOCA                North Cascades National Park          WA   504781
# 41      OLYM                       Olympic National Park          WA   922651
# 42      PEFO              Petrified Forest National Park          AZ    93533
# 43      PINN                     Pinnacles National Park          CA    26606
# 44      REDW                       Redwood National Park          CA   112512
# 45      ROMO                Rocky Mountain National Park          CO   265828
# 46      SAGU                       Saguaro National Park          AZ    91440
# 47      SEKI      Sequoia and Kings Canyon National Park          CA   865952
# 48      SHEN                    Shenandoah National Park          VA   199045
# 49      THRO            Theodore Roosevelt National Park          ND    70447
# 50      VOYA                     Voyageurs National Park          MN   218200
# 51      WICA                     Wind Cave National Park          SD    28295
# 52      WRST           Wrangell - St Elias National Park          AK  8323148
# 53      YELL                   Yellowstone National Park  WY, MT, ID  2219791
# 54      YOSE                      Yosemite National Park          CA   761266
# 55      ZION                          Zion National Park          UT   146598
#
#     latitude  longitude
# 0      44.35     -68.21
# 1      38.68    -109.57
# 2      43.75    -102.50
# 3      29.25    -103.25
# 4      25.65     -80.08
# 5      38.57    -107.72
# 6      37.57    -112.18
# 7      38.20    -109.93
# 8      38.20    -111.17
# 9      32.17    -104.44
# 10     34.01    -119.42
# 11     33.78     -80.78
# 12     42.94    -122.10
# 13     41.24     -81.55
# 14     63.33    -150.50
# 15     36.24    -116.82
# 16     24.63     -82.87
# 17     25.32     -80.93
# 18     67.78    -153.30
# 19     48.80    -114.00
# 20     58.50    -137.00
# 21     38.98    -114.30
# 22     36.06    -112.14
# 23     37.73    -105.51
# 24     35.68     -83.53
# 25     43.73    -110.80
# 26     31.92    -104.87
# 27     20.72    -156.17
# 28     19.38    -155.20
# 29     34.51     -93.05
# 30     48.10     -88.55
# 31     33.79    -115.90
# 32     58.50    -155.00
# 33     59.92    -149.65
# 34     67.55    -159.28
# 35     60.97    -153.42
# 36     40.49    -121.51
# 37     37.18     -86.10
# 38     37.18    -108.49
# 39     46.85    -121.75
# 40     48.70    -121.20
# 41     47.97    -123.50
# 42     35.07    -109.78
# 43     36.48    -121.16
# 44     41.30    -124.00
# 45     40.40    -105.58
# 46     32.25    -110.50
# 47     36.43    -118.68
# 48     38.53     -78.35
# 49     46.97    -103.45
# 50     48.50     -92.88
# 51     43.57    -103.48
# 52     61.00    -142.00
# 53     44.60    -110.50
# 54     37.83    -119.50
# 55     37.30    -113.05

# %%
# Write parks final df to CSV:

merged_data_to_load = "./Resources/parks_final.csv"
parks_final_df.to_csv(merged_data_to_load, index=False)

# %% [markdown]
# #### NOTE: parks_final_df is clean and ready to merge with trails data

# %% [markdown]
# ### Trails Data

# %%
# Load the trail data from trail_data.csv:

trails_data_to_load = "./Resources/trail_data.csv"
trails_df = pd.read_csv(trails_data_to_load, low_memory=False, encoding="utf-8")
trails_df.head(5)
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1161.8976                  5  out and back            3.0         5.0
# 1        507.7968                  3  out and back            1.0         4.5
# 2         81.9912                  1  out and back            3.0         4.5
# 3        119.7864                  1          loop            2.0         4.5
# 4       1124.7120                  5  out and back            1.0         4.5
#
#    num_reviews                                           features  \
# 0          423  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1          260  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2          224  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3          237  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4          110  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities units
# 0  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                              ['hiking', 'walking']     i
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     i

# %%
#Standardize the column names to lowercase & underscores:

renamed_trails_df = trails_df.rename(columns={"area_name": "park_name"})
renamed_trails_df.head()
# Out:
#    trail_id                        name                   park_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1161.8976                  5  out and back            3.0         5.0
# 1        507.7968                  3  out and back            1.0         4.5
# 2         81.9912                  1  out and back            3.0         4.5
# 3        119.7864                  1          loop            2.0         4.5
# 4       1124.7120                  5  out and back            1.0         4.5
#
#    num_reviews                                           features  \
# 0          423  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1          260  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2          224  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3          237  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4          110  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities units
# 0  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                              ['hiking', 'walking']     i
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     i

# %%
# Remove any words after the work "Park" in park_names
p = '(.*Park)'
park_name_trails = renamed_trails_df["park_name"].str.extract(p)

#Checking the regex function
park_name_trails.value_counts()
# Out:
# Great Smoky Mountains National Park           293
# Yosemite National Park                        242
# Yellowstone National Park                     228
# Rocky Mountain National Park                  207
# Shenandoah National Park                      187
# Acadia National Park                          179
# Olympic National Park                         170
# Glacier National Park                         132
# Mount Rainier National Park                   130
# Joshua Tree National Park                     108
# Grand Teton National Park                     102
# Grand Canyon National Park                     99
# Zion National Park                             94
# Sequoia National Park                          90
# Death Valley National Park                     79
# Canyonlands National Park                      77
# Big Bend National Park                         70
# Kings Canyon National Park                     61
# Saguaro National Park                          60
# Lassen Volcanic National Park                  59
# Cuyahoga Valley National Park                  50
# Arches National Park                           48
# Capitol Reef National Park                     42
# Hawaii Volcanoes National Park                 35
# Bryce Canyon National Park                     31
# Mammoth Cave National Park                     28
# Pinnacles National Park                        27
# Guadalupe Mountains National Park              24
# Black Canyon of the Gunnison National Park     24
# Everglades National Park                       24
# Theodore Roosevelt National Park               23
# Redwood National Park                          22
# Crater Lake National Park                      22
# Great Basin National Park                      22
# Channel Islands National Park                  22
# Denali National Park                           20
# North Cascades National Park                   20
# Mesa Verde National Park                       17
# Indiana Dunes National Park                    16
# Hot Springs National Park                      16
# Petrified Forest National Park                 15
# Haleakala National Park                        14
# Great Sand Dunes National Park                 14
# Badlands National Park                         10
# Wind Cave National Park                        10
# Congaree National Park                          8
# Carlsbad Caverns National Park                  8
# Voyageurs National Park                         7
# Glacier Bay National Park                       5
# Isle Royale National Park                       4
# Biscayne National Park                          4
# Fort Hunt National Park                         3
# Gateway Arch National Park                      2
# Fort Pickens National Park                      2
# Kenai Fjords National Park                      2
# Katmai National Park                            2
# Dry Tortugas National Park                      1
# Clayton Co International Park                   1
# Wolf Trap National Park                         1
# dtype: int64

# %%
# Park Names have been trimmed and are moved inplace of the original park names 
# A new dataframe is named (renamed_trails_df)

renamed_trails_df["park_name"] = park_name_trails.values
renamed_trails_df
# Out:
#       trail_id                                               name  \
# 0     10020048                            Harding Ice Field Trail
# 1     10236086                         Mount Healy Overlook Trail
# 2     10267857                                 Exit Glacier Trail
# 3     10236076                               Horseshoe Lake Trail
# 4     10236082                                 Triple Lakes Trail
# ...        ...                                                ...
# 3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309  10236001                                Keonehe'ehe'e Trail
# 3310  10258707                     Red Hill Overlook Summit Trail
# 3311  10014989                                        Kaupo Trail
# 3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        park_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# 1           Denali National Park  Denali National Park     Alaska
# 2     Kenai Fjords National Park                Seward     Alaska
# 3           Denali National Park  Denali National Park     Alaska
# 4           Denali National Park  Denali National Park     Alaska
# ...                          ...                   ...        ...
# 3308     Haleakala National Park                  Kula       Maui
# 3309     Haleakala National Park                  Kula       Maui
# 3310     Haleakala National Park                  Kula       Maui
# 3311     Haleakala National Park                  Kula       Maui
# 3312     Haleakala National Park                  Kula       Maui
#
#        country_name                                         _geoloc  \
# 0     United States            {'lat': 60.18852, 'lng': -149.63156}
# 1     United States            {'lat': 63.73049, 'lng': -148.91968}
# 2     United States              {'lat': 60.18879, 'lng': -149.631}
# 3     United States              {'lat': 63.73661, 'lng': -148.915}
# 4     United States            {'lat': 63.73319, 'lng': -148.89682}
# ...             ...                                             ...
# 3308         Hawaii            {'lat': 20.75275, 'lng': -156.22884}
# 3309         Hawaii  {'lat': 20.714480000000002, 'lng': -156.25072}
# 3310         Hawaii            {'lat': 20.71007, 'lng': -156.25357}
# 3311         Hawaii              {'lat': 20.64981, 'lng': -156.137}
# 3312         Hawaii            {'lat': 20.71449, 'lng': -156.25085}
#
#       popularity     length  elevation_gain  difficulty_rating    route_type  \
# 0        24.8931  15610.598       1161.8976                  5  out and back
# 1        18.0311   6920.162        507.7968                  3  out and back
# 2        17.7821   2896.812         81.9912                  1  out and back
# 3        16.2674   3379.614        119.7864                  1          loop
# 4        12.5935  29772.790       1124.7120                  5  out and back
# ...          ...        ...             ...                ...           ...
# 3308      9.3861  20116.750       1105.8144                  5          loop
# 3309      9.1555  28324.384       1171.9560                  5  out and back
# 3310      8.5066    321.868          3.9624                  1  out and back
# 3311      8.3240  19312.080       1670.9136                  5  out and back
# 3312      2.4176   8368.568        510.8448                  3          loop
#
#       visitor_usage  avg_rating  num_reviews  \
# 0               3.0         5.0          423
# 1               1.0         4.5          260
# 2               3.0         4.5          224
# 3               2.0         4.5          237
# 4               1.0         4.5          110
# ...             ...         ...          ...
# 3308            2.0         4.5           43
# 3309            2.0         5.0           22
# 3310            NaN         4.5           31
# 3311            1.0         4.0            8
# 3312            2.0         4.5           45
#
#                                                features  \
# 0     ['dogs-no', 'forest', 'river', 'views', 'water...
# 1     ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2     ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3     ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4     ['dogs-no', 'lake', 'views', 'wild-flowers', '...
# ...                                                 ...
# 3308               ['dogs-no', 'views', 'wild-flowers']
# 3309                   ['dogs-no', 'views', 'wildlife']
# 3310                       ['dogs-no', 'kids', 'views']
# 3311                   ['dogs-no', 'views', 'wildlife']
# 3312                                          ['views']
#
#                                              activities units
# 0     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                                 ['hiking', 'walking']     i
# 3     ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4     ['birding', 'fishing', 'hiking', 'nature-trips...     i
# ...                                                 ...   ...
# 3308              ['birding', 'hiking', 'nature-trips']     m
# 3309               ['backpacking', 'camping', 'hiking']     m
# 3310                              ['hiking', 'walking']     m
# 3311                                         ['hiking']     m
# 3312                                         ['hiking']     m
#
# [3313 rows x 18 columns]

# %%
# Use pd.replace to replace "Sequoia National Park" and "Kings Canyon National Park"
# with "Sequoia and Kings Canyon National Park":

renamed_trails_df['park_name'] = renamed_trails_df['park_name'].replace(['Kings Canyon National Park','Sequoia National Park'],'Sequoia and Kings Canyon National Park')
trails_final_df = renamed_trails_df
trails_final_df
# Out:
#       trail_id                                               name  \
# 0     10020048                            Harding Ice Field Trail
# 1     10236086                         Mount Healy Overlook Trail
# 2     10267857                                 Exit Glacier Trail
# 3     10236076                               Horseshoe Lake Trail
# 4     10236082                                 Triple Lakes Trail
# ...        ...                                                ...
# 3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309  10236001                                Keonehe'ehe'e Trail
# 3310  10258707                     Red Hill Overlook Summit Trail
# 3311  10014989                                        Kaupo Trail
# 3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        park_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# 1           Denali National Park  Denali National Park     Alaska
# 2     Kenai Fjords National Park                Seward     Alaska
# 3           Denali National Park  Denali National Park     Alaska
# 4           Denali National Park  Denali National Park     Alaska
# ...                          ...                   ...        ...
# 3308     Haleakala National Park                  Kula       Maui
# 3309     Haleakala National Park                  Kula       Maui
# 3310     Haleakala National Park                  Kula       Maui
# 3311     Haleakala National Park                  Kula       Maui
# 3312     Haleakala National Park                  Kula       Maui
#
#        country_name                                         _geoloc  \
# 0     United States            {'lat': 60.18852, 'lng': -149.63156}
# 1     United States            {'lat': 63.73049, 'lng': -148.91968}
# 2     United States              {'lat': 60.18879, 'lng': -149.631}
# 3     United States              {'lat': 63.73661, 'lng': -148.915}
# 4     United States            {'lat': 63.73319, 'lng': -148.89682}
# ...             ...                                             ...
# 3308         Hawaii            {'lat': 20.75275, 'lng': -156.22884}
# 3309         Hawaii  {'lat': 20.714480000000002, 'lng': -156.25072}
# 3310         Hawaii            {'lat': 20.71007, 'lng': -156.25357}
# 3311         Hawaii              {'lat': 20.64981, 'lng': -156.137}
# 3312         Hawaii            {'lat': 20.71449, 'lng': -156.25085}
#
#       popularity     length  elevation_gain  difficulty_rating    route_type  \
# 0        24.8931  15610.598       1161.8976                  5  out and back
# 1        18.0311   6920.162        507.7968                  3  out and back
# 2        17.7821   2896.812         81.9912                  1  out and back
# 3        16.2674   3379.614        119.7864                  1          loop
# 4        12.5935  29772.790       1124.7120                  5  out and back
# ...          ...        ...             ...                ...           ...
# 3308      9.3861  20116.750       1105.8144                  5          loop
# 3309      9.1555  28324.384       1171.9560                  5  out and back
# 3310      8.5066    321.868          3.9624                  1  out and back
# 3311      8.3240  19312.080       1670.9136                  5  out and back
# 3312      2.4176   8368.568        510.8448                  3          loop
#
#       visitor_usage  avg_rating  num_reviews  \
# 0               3.0         5.0          423
# 1               1.0         4.5          260
# 2               3.0         4.5          224
# 3               2.0         4.5          237
# 4               1.0         4.5          110
# ...             ...         ...          ...
# 3308            2.0         4.5           43
# 3309            2.0         5.0           22
# 3310            NaN         4.5           31
# 3311            1.0         4.0            8
# 3312            2.0         4.5           45
#
#                                                features  \
# 0     ['dogs-no', 'forest', 'river', 'views', 'water...
# 1     ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2     ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3     ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4     ['dogs-no', 'lake', 'views', 'wild-flowers', '...
# ...                                                 ...
# 3308               ['dogs-no', 'views', 'wild-flowers']
# 3309                   ['dogs-no', 'views', 'wildlife']
# 3310                       ['dogs-no', 'kids', 'views']
# 3311                   ['dogs-no', 'views', 'wildlife']
# 3312                                          ['views']
#
#                                              activities units
# 0     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                                 ['hiking', 'walking']     i
# 3     ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4     ['birding', 'fishing', 'hiking', 'nature-trips...     i
# ...                                                 ...   ...
# 3308              ['birding', 'hiking', 'nature-trips']     m
# 3309               ['backpacking', 'camping', 'hiking']     m
# 3310                              ['hiking', 'walking']     m
# 3311                                         ['hiking']     m
# 3312                                         ['hiking']     m
#
# [3313 rows x 18 columns]

# %%
# Write trails final df to CSV:

merged_data_to_load = "./Resources/trails_final.csv"
trails_final_df.to_csv(merged_data_to_load, index=False)

# %%
# Create a value for the number of trails per park
# Sequoia and Kings Canyon National Park should equal 90 + 61):

trail_count = trails_final_df.groupby(["park_name"]).count()["trail_id"].sort_values(ascending=False)
trail_count
# Out:
# park_name
# Great Smoky Mountains National Park           293
# Yosemite National Park                        242
# Yellowstone National Park                     228
# Rocky Mountain National Park                  207
# Shenandoah National Park                      187
# Acadia National Park                          179
# Olympic National Park                         170
# Sequoia and Kings Canyon National Park        151
# Glacier National Park                         132
# Mount Rainier National Park                   130
# Joshua Tree National Park                     108
# Grand Teton National Park                     102
# Grand Canyon National Park                     99
# Zion National Park                             94
# Death Valley National Park                     79
# Canyonlands National Park                      77
# Big Bend National Park                         70
# Saguaro National Park                          60
# Lassen Volcanic National Park                  59
# Cuyahoga Valley National Park                  50
# Arches National Park                           48
# Capitol Reef National Park                     42
# Hawaii Volcanoes National Park                 35
# Bryce Canyon National Park                     31
# Mammoth Cave National Park                     28
# Pinnacles National Park                        27
# Black Canyon of the Gunnison National Park     24
# Guadalupe Mountains National Park              24
# Everglades National Park                       24
# Theodore Roosevelt National Park               23
# Channel Islands National Park                  22
# Redwood National Park                          22
# Crater Lake National Park                      22
# Great Basin National Park                      22
# North Cascades National Park                   20
# Denali National Park                           20
# Mesa Verde National Park                       17
# Hot Springs National Park                      16
# Indiana Dunes National Park                    16
# Petrified Forest National Park                 15
# Great Sand Dunes National Park                 14
# Haleakala National Park                        14
# Badlands National Park                         10
# Wind Cave National Park                        10
# Congaree National Park                          8
# Carlsbad Caverns National Park                  8
# Voyageurs National Park                         7
# Glacier Bay National Park                       5
# Isle Royale National Park                       4
# Biscayne National Park                          4
# Fort Hunt National Park                         3
# Gateway Arch National Park                      2
# Fort Pickens National Park                      2
# Kenai Fjords National Park                      2
# Katmai National Park                            2
# Dry Tortugas National Park                      1
# Wolf Trap National Park                         1
# Clayton Co International Park                   1
# Name: trail_id, dtype: int64

# %%
# Create a value for the average popularity score for all trails within a certain park:

trail_pop_avg = trails_final_df.groupby(["park_name"]).mean()["popularity"].sort_values(ascending=False)
print(trail_pop_avg)
# Out:
# park_name
# Kenai Fjords National Park                    21.337600
# Bryce Canyon National Park                    16.617903
# Haleakala National Park                       13.723586
# Arches National Park                          13.462423
# Badlands National Park                        13.141040
# Rocky Mountain National Park                  13.007846
# Crater Lake National Park                     12.430750
# Zion National Park                            12.027557
# Mount Rainier National Park                   11.726444
# Glacier National Park                         10.061925
# Grand Canyon National Park                     9.716001
# Pinnacles National Park                        9.421904
# Olympic National Park                          9.389508
# North Cascades National Park                   9.374660
# Grand Teton National Park                      9.373725
# Sequoia and Kings Canyon National Park         9.243440
# Yosemite National Park                         9.235686
# Capitol Reef National Park                     9.006231
# Cuyahoga Valley National Park                  8.771132
# Shenandoah National Park                       8.517370
# Great Sand Dunes National Park                 8.381900
# Acadia National Park                           8.375920
# Great Smoky Mountains National Park            8.313232
# Mesa Verde National Park                       8.225906
# Canyonlands National Park                      8.143584
# Joshua Tree National Park                      7.860079
# Black Canyon of the Gunnison National Park     7.690121
# Petrified Forest National Park                 7.688287
# Hot Springs National Park                      7.326819
# Big Bend National Park                         7.176380
# Redwood National Park                          7.145291
# Lassen Volcanic National Park                  7.117390
# Wolf Trap National Park                        7.111900
# Guadalupe Mountains National Park              7.075000
# Yellowstone National Park                      7.006884
# Congaree National Park                         6.675575
# Saguaro National Park                          6.639557
# Fort Pickens National Park                     6.373850
# Death Valley National Park                     6.359223
# Great Basin National Park                      6.347132
# Hawaii Volcanoes National Park                 6.123489
# Denali National Park                           6.091125
# Mammoth Cave National Park                     5.800725
# Theodore Roosevelt National Park               5.785835
# Channel Islands National Park                  5.626650
# Wind Cave National Park                        5.500610
# Carlsbad Caverns National Park                 5.329462
# Gateway Arch National Park                     5.306350
# Dry Tortugas National Park                     5.177600
# Indiana Dunes National Park                    5.099050
# Fort Hunt National Park                        4.921167
# Clayton Co International Park                  4.729100
# Everglades National Park                       4.532038
# Biscayne National Park                         4.055200
# Voyageurs National Park                        3.040929
# Isle Royale National Park                      3.018375
# Katmai National Park                           2.263250
# Glacier Bay National Park                      2.159100
# Name: popularity, dtype: float64

# %%
# Create a new df that contains the count of trails and the average poplarity of each park:

trail_count_pop_df = pd.DataFrame({
    "trail_count": trail_count,
    "avg_popularity": trail_pop_avg,
})

#Reset the index so the park name is no longer the index:

trail_count_pop_df.reset_index(inplace=True)
trail_count_pop_df = trail_count_pop_df.rename(columns = {'index':'park_name'})

trail_count_pop_df
# Out:
#                                      park_name  trail_count  avg_popularity
# 0                         Acadia National Park          179        8.375920
# 1                         Arches National Park           48       13.462423
# 2                       Badlands National Park           10       13.141040
# 3                       Big Bend National Park           70        7.176380
# 4                       Biscayne National Park            4        4.055200
# 5   Black Canyon of the Gunnison National Park           24        7.690121
# 6                   Bryce Canyon National Park           31       16.617903
# 7                    Canyonlands National Park           77        8.143584
# 8                   Capitol Reef National Park           42        9.006231
# 9               Carlsbad Caverns National Park            8        5.329462
# 10               Channel Islands National Park           22        5.626650
# 11               Clayton Co International Park            1        4.729100
# 12                      Congaree National Park            8        6.675575
# 13                   Crater Lake National Park           22       12.430750
# 14               Cuyahoga Valley National Park           50        8.771132
# 15                  Death Valley National Park           79        6.359223
# 16                        Denali National Park           20        6.091125
# 17                  Dry Tortugas National Park            1        5.177600
# 18                    Everglades National Park           24        4.532038
# 19                     Fort Hunt National Park            3        4.921167
# 20                  Fort Pickens National Park            2        6.373850
# 21                  Gateway Arch National Park            2        5.306350
# 22                   Glacier Bay National Park            5        2.159100
# 23                       Glacier National Park          132       10.061925
# 24                  Grand Canyon National Park           99        9.716001
# 25                   Grand Teton National Park          102        9.373725
# 26                   Great Basin National Park           22        6.347132
# 27              Great Sand Dunes National Park           14        8.381900
# 28         Great Smoky Mountains National Park          293        8.313232
# 29           Guadalupe Mountains National Park           24        7.075000
# 30                     Haleakala National Park           14       13.723586
# 31              Hawaii Volcanoes National Park           35        6.123489
# 32                   Hot Springs National Park           16        7.326819
# 33                 Indiana Dunes National Park           16        5.099050
# 34                   Isle Royale National Park            4        3.018375
# 35                   Joshua Tree National Park          108        7.860079
# 36                        Katmai National Park            2        2.263250
# 37                  Kenai Fjords National Park            2       21.337600
# 38               Lassen Volcanic National Park           59        7.117390
# 39                  Mammoth Cave National Park           28        5.800725
# 40                    Mesa Verde National Park           17        8.225906
# 41                 Mount Rainier National Park          130       11.726444
# 42                North Cascades National Park           20        9.374660
# 43                       Olympic National Park          170        9.389508
# 44              Petrified Forest National Park           15        7.688287
# 45                     Pinnacles National Park           27        9.421904
# 46                       Redwood National Park           22        7.145291
# 47                Rocky Mountain National Park          207       13.007846
# 48                       Saguaro National Park           60        6.639557
# 49      Sequoia and Kings Canyon National Park          151        9.243440
# 50                    Shenandoah National Park          187        8.517370
# 51            Theodore Roosevelt National Park           23        5.785835
# 52                     Voyageurs National Park            7        3.040929
# 53                     Wind Cave National Park           10        5.500610
# 54                     Wolf Trap National Park            1        7.111900
# 55                   Yellowstone National Park          228        7.006884
# 56                      Yosemite National Park          242        9.235686
# 57                          Zion National Park           94       12.027557

# %%
# Write trail count pop df to CSV:

merged_data_to_load = "./Resources/trail_count_pop.csv"
trail_count_pop_df.to_csv(merged_data_to_load, index=False)

# %% [markdown]
# #### NOTE: trail_count_pop_df is clean and ready to merge with parks_final_df

# %% [markdown]
# ### Merging Parks and Trail Popularity DataFrames

# %%
#Create a dataframe that populates the parks_df with trail count and popularity data from the trails df:
merged_parks_df = pd.merge(parks_final_df, trail_count_pop_df, on="park_name", how="left")
pd.options.display.max_rows = 100
merged_parks_df
# Out:
#    park_code                                   park_name       state    acres  \
# 0       ACAD                        Acadia National Park          ME    47390
# 1       ARCH                        Arches National Park          UT    76519
# 2       BADL                      Badlands National Park          SD   242756
# 3       BIBE                      Big Bend National Park          TX   801163
# 4       BISC                      Biscayne National Park          FL   172924
# 5       BLCA  Black Canyon of the Gunnison National Park          CO    32950
# 6       BRCA                  Bryce Canyon National Park          UT    35835
# 7       CANY                   Canyonlands National Park          UT   337598
# 8       CARE                  Capitol Reef National Park          UT   241904
# 9       CAVE              Carlsbad Caverns National Park          NM    46766
# 10      CHIS               Channel Islands National Park          CA   249561
# 11      CONG                      Congaree National Park          SC    26546
# 12      CRLA                   Crater Lake National Park          OR   183224
# 13      CUVA               Cuyahoga Valley National Park          OH    32950
# 14      DENA                        Denali National Park          AK  3372402
# 15      DEVA                  Death Valley National Park      CA, NV  4740912
# 16      DRTO                  Dry Tortugas National Park          FL    64701
# 17      EVER                    Everglades National Park          FL  1508538
# 18      GAAR           Gates Of The Arctic National Park          AK  7523898
# 19      GLAC                       Glacier National Park          MT  1013572
# 20      GLBA                   Glacier Bay National Park          AK  3224840
# 21      GRBA                   Great Basin National Park          NV    77180
# 22      GRCA                  Grand Canyon National Park          AZ  1217403
# 23      GRSA              Great Sand Dunes National Park          CO    42984
# 24      GRSM         Great Smoky Mountains National Park      TN, NC   521490
# 25      GRTE                   Grand Teton National Park          WY   309995
# 26      GUMO           Guadalupe Mountains National Park          TX    86416
# 27      HALE                     Haleakala National Park          HI    29094
# 28      HAVO              Hawaii Volcanoes National Park          HI   323431
# 29      HOSP                   Hot Springs National Park          AR     5550
# 30      ISRO                   Isle Royale National Park          MI   571790
# 31      JOTR                   Joshua Tree National Park          CA   789745
# 32      KATM                        Katmai National Park          AK  3674530
# 33      KEFJ                  Kenai Fjords National Park          AK   669983
# 34      KOVA                  Kobuk Valley National Park          AK  1750717
# 35      LACL                    Lake Clark National Park          AK  2619733
# 36      LAVO               Lassen Volcanic National Park          CA   106372
# 37      MACA                  Mammoth Cave National Park          KY    52830
# 38      MEVE                    Mesa Verde National Park          CO    52122
# 39      MORA                 Mount Rainier National Park          WA   235625
# 40      NOCA                North Cascades National Park          WA   504781
# 41      OLYM                       Olympic National Park          WA   922651
# 42      PEFO              Petrified Forest National Park          AZ    93533
# 43      PINN                     Pinnacles National Park          CA    26606
# 44      REDW                       Redwood National Park          CA   112512
# 45      ROMO                Rocky Mountain National Park          CO   265828
# 46      SAGU                       Saguaro National Park          AZ    91440
# 47      SEKI      Sequoia and Kings Canyon National Park          CA   865952
# 48      SHEN                    Shenandoah National Park          VA   199045
# 49      THRO            Theodore Roosevelt National Park          ND    70447
# 50      VOYA                     Voyageurs National Park          MN   218200
# 51      WICA                     Wind Cave National Park          SD    28295
# 52      WRST           Wrangell - St Elias National Park          AK  8323148
# 53      YELL                   Yellowstone National Park  WY, MT, ID  2219791
# 54      YOSE                      Yosemite National Park          CA   761266
# 55      ZION                          Zion National Park          UT   146598
#
#     latitude  longitude  trail_count  avg_popularity
# 0      44.35     -68.21        179.0        8.375920
# 1      38.68    -109.57         48.0       13.462423
# 2      43.75    -102.50         10.0       13.141040
# 3      29.25    -103.25         70.0        7.176380
# 4      25.65     -80.08          4.0        4.055200
# 5      38.57    -107.72         24.0        7.690121
# 6      37.57    -112.18         31.0       16.617903
# 7      38.20    -109.93         77.0        8.143584
# 8      38.20    -111.17         42.0        9.006231
# 9      32.17    -104.44          8.0        5.329462
# 10     34.01    -119.42         22.0        5.626650
# 11     33.78     -80.78          8.0        6.675575
# 12     42.94    -122.10         22.0       12.430750
# 13     41.24     -81.55         50.0        8.771132
# 14     63.33    -150.50         20.0        6.091125
# 15     36.24    -116.82         79.0        6.359223
# 16     24.63     -82.87          1.0        5.177600
# 17     25.32     -80.93         24.0        4.532038
# 18     67.78    -153.30          NaN             NaN
# 19     48.80    -114.00        132.0       10.061925
# 20     58.50    -137.00          5.0        2.159100
# 21     38.98    -114.30         22.0        6.347132
# 22     36.06    -112.14         99.0        9.716001
# 23     37.73    -105.51         14.0        8.381900
# 24     35.68     -83.53        293.0        8.313232
# 25     43.73    -110.80        102.0        9.373725
# 26     31.92    -104.87         24.0        7.075000
# 27     20.72    -156.17         14.0       13.723586
# 28     19.38    -155.20         35.0        6.123489
# 29     34.51     -93.05         16.0        7.326819
# 30     48.10     -88.55          4.0        3.018375
# 31     33.79    -115.90        108.0        7.860079
# 32     58.50    -155.00          2.0        2.263250
# 33     59.92    -149.65          2.0       21.337600
# 34     67.55    -159.28          NaN             NaN
# 35     60.97    -153.42          NaN             NaN
# 36     40.49    -121.51         59.0        7.117390
# 37     37.18     -86.10         28.0        5.800725
# 38     37.18    -108.49         17.0        8.225906
# 39     46.85    -121.75        130.0       11.726444
# 40     48.70    -121.20         20.0        9.374660
# 41     47.97    -123.50        170.0        9.389508
# 42     35.07    -109.78         15.0        7.688287
# 43     36.48    -121.16         27.0        9.421904
# 44     41.30    -124.00         22.0        7.145291
# 45     40.40    -105.58        207.0       13.007846
# 46     32.25    -110.50         60.0        6.639557
# 47     36.43    -118.68        151.0        9.243440
# 48     38.53     -78.35        187.0        8.517370
# 49     46.97    -103.45         23.0        5.785835
# 50     48.50     -92.88          7.0        3.040929
# 51     43.57    -103.48         10.0        5.500610
# 52     61.00    -142.00          NaN             NaN
# 53     44.60    -110.50        228.0        7.006884
# 54     37.83    -119.50        242.0        9.235686
# 55     37.30    -113.05         94.0       12.027557

# %%
#Check the rows with NaNs in the trails data columns:

merged_parks_df.isna().sum()
# Out:
# park_code         0
# park_name         0
# state             0
# acres             0
# latitude          0
# longitude         0
# trail_count       4
# avg_popularity    4
# dtype: int64

# %%
#Drop the rows with NaNs in the trails data columns:

parks_trails_final_df = merged_parks_df.dropna(axis=0)
parks_trails_final_df
# Out:
#    park_code                                   park_name       state    acres  \
# 0       ACAD                        Acadia National Park          ME    47390
# 1       ARCH                        Arches National Park          UT    76519
# 2       BADL                      Badlands National Park          SD   242756
# 3       BIBE                      Big Bend National Park          TX   801163
# 4       BISC                      Biscayne National Park          FL   172924
# 5       BLCA  Black Canyon of the Gunnison National Park          CO    32950
# 6       BRCA                  Bryce Canyon National Park          UT    35835
# 7       CANY                   Canyonlands National Park          UT   337598
# 8       CARE                  Capitol Reef National Park          UT   241904
# 9       CAVE              Carlsbad Caverns National Park          NM    46766
# 10      CHIS               Channel Islands National Park          CA   249561
# 11      CONG                      Congaree National Park          SC    26546
# 12      CRLA                   Crater Lake National Park          OR   183224
# 13      CUVA               Cuyahoga Valley National Park          OH    32950
# 14      DENA                        Denali National Park          AK  3372402
# 15      DEVA                  Death Valley National Park      CA, NV  4740912
# 16      DRTO                  Dry Tortugas National Park          FL    64701
# 17      EVER                    Everglades National Park          FL  1508538
# 19      GLAC                       Glacier National Park          MT  1013572
# 20      GLBA                   Glacier Bay National Park          AK  3224840
# 21      GRBA                   Great Basin National Park          NV    77180
# 22      GRCA                  Grand Canyon National Park          AZ  1217403
# 23      GRSA              Great Sand Dunes National Park          CO    42984
# 24      GRSM         Great Smoky Mountains National Park      TN, NC   521490
# 25      GRTE                   Grand Teton National Park          WY   309995
# 26      GUMO           Guadalupe Mountains National Park          TX    86416
# 27      HALE                     Haleakala National Park          HI    29094
# 28      HAVO              Hawaii Volcanoes National Park          HI   323431
# 29      HOSP                   Hot Springs National Park          AR     5550
# 30      ISRO                   Isle Royale National Park          MI   571790
# 31      JOTR                   Joshua Tree National Park          CA   789745
# 32      KATM                        Katmai National Park          AK  3674530
# 33      KEFJ                  Kenai Fjords National Park          AK   669983
# 36      LAVO               Lassen Volcanic National Park          CA   106372
# 37      MACA                  Mammoth Cave National Park          KY    52830
# 38      MEVE                    Mesa Verde National Park          CO    52122
# 39      MORA                 Mount Rainier National Park          WA   235625
# 40      NOCA                North Cascades National Park          WA   504781
# 41      OLYM                       Olympic National Park          WA   922651
# 42      PEFO              Petrified Forest National Park          AZ    93533
# 43      PINN                     Pinnacles National Park          CA    26606
# 44      REDW                       Redwood National Park          CA   112512
# 45      ROMO                Rocky Mountain National Park          CO   265828
# 46      SAGU                       Saguaro National Park          AZ    91440
# 47      SEKI      Sequoia and Kings Canyon National Park          CA   865952
# 48      SHEN                    Shenandoah National Park          VA   199045
# 49      THRO            Theodore Roosevelt National Park          ND    70447
# 50      VOYA                     Voyageurs National Park          MN   218200
# 51      WICA                     Wind Cave National Park          SD    28295
# 53      YELL                   Yellowstone National Park  WY, MT, ID  2219791
# 54      YOSE                      Yosemite National Park          CA   761266
# 55      ZION                          Zion National Park          UT   146598
#
#     latitude  longitude  trail_count  avg_popularity
# 0      44.35     -68.21        179.0        8.375920
# 1      38.68    -109.57         48.0       13.462423
# 2      43.75    -102.50         10.0       13.141040
# 3      29.25    -103.25         70.0        7.176380
# 4      25.65     -80.08          4.0        4.055200
# 5      38.57    -107.72         24.0        7.690121
# 6      37.57    -112.18         31.0       16.617903
# 7      38.20    -109.93         77.0        8.143584
# 8      38.20    -111.17         42.0        9.006231
# 9      32.17    -104.44          8.0        5.329462
# 10     34.01    -119.42         22.0        5.626650
# 11     33.78     -80.78          8.0        6.675575
# 12     42.94    -122.10         22.0       12.430750
# 13     41.24     -81.55         50.0        8.771132
# 14     63.33    -150.50         20.0        6.091125
# 15     36.24    -116.82         79.0        6.359223
# 16     24.63     -82.87          1.0        5.177600
# 17     25.32     -80.93         24.0        4.532038
# 19     48.80    -114.00        132.0       10.061925
# 20     58.50    -137.00          5.0        2.159100
# 21     38.98    -114.30         22.0        6.347132
# 22     36.06    -112.14         99.0        9.716001
# 23     37.73    -105.51         14.0        8.381900
# 24     35.68     -83.53        293.0        8.313232
# 25     43.73    -110.80        102.0        9.373725
# 26     31.92    -104.87         24.0        7.075000
# 27     20.72    -156.17         14.0       13.723586
# 28     19.38    -155.20         35.0        6.123489
# 29     34.51     -93.05         16.0        7.326819
# 30     48.10     -88.55          4.0        3.018375
# 31     33.79    -115.90        108.0        7.860079
# 32     58.50    -155.00          2.0        2.263250
# 33     59.92    -149.65          2.0       21.337600
# 36     40.49    -121.51         59.0        7.117390
# 37     37.18     -86.10         28.0        5.800725
# 38     37.18    -108.49         17.0        8.225906
# 39     46.85    -121.75        130.0       11.726444
# 40     48.70    -121.20         20.0        9.374660
# 41     47.97    -123.50        170.0        9.389508
# 42     35.07    -109.78         15.0        7.688287
# 43     36.48    -121.16         27.0        9.421904
# 44     41.30    -124.00         22.0        7.145291
# 45     40.40    -105.58        207.0       13.007846
# 46     32.25    -110.50         60.0        6.639557
# 47     36.43    -118.68        151.0        9.243440
# 48     38.53     -78.35        187.0        8.517370
# 49     46.97    -103.45         23.0        5.785835
# 50     48.50     -92.88          7.0        3.040929
# 51     43.57    -103.48         10.0        5.500610
# 53     44.60    -110.50        228.0        7.006884
# 54     37.83    -119.50        242.0        9.235686
# 55     37.30    -113.05         94.0       12.027557

# %%
# Write final df to CSV:

merged_data_to_load = "./Resources/parks_trails_final.csv"
parks_trails_final_df.to_csv(merged_data_to_load, index=False)
